# %% [markdown]
# This notebook contains functionality to perform the following:
#
# Check how fast it is to run model training (MLME-v2.0-conv_model.py) on Google Colab with various hardware accelerators. The time taken to run one epoch on my local machine with these same settings was ~45s.

# %%
# mount google drive

from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/Shareddrives/NRC_Amii_Agronomics_Project/nrc-ml-plant-genomics/'

# %%
import time

# %%
# NO ACC
t0 = time.time()
# !python MLME-v2.0-conv_model.py -lr 0.01 -bs 32 -ep 20 -pa 5
print(time.time()-t0)
# Out:
# 2021-06-15 16:23:58.841605: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-15 16:24:05.748787: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-15 16:24:05.762310: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-06-15 16:24:05.762373: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7f886dc22e31): /proc/driver/nvidia/version does not exist
# 2021-06-15 16:24:05.983275: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-06-15 16:24:05.983355: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# ...

# %%
# GPU
t0 = time.time()
# !python src/MLME-v2.0-conv_model.py -lr 0.01 -bs 32 -ep 20 -pa 5
print(time.time()-t0)
# Out:
# 2021-06-15 16:40:22.360472: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-15 16:40:29.748099: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-15 16:40:29.806908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-15 16:40:29.807562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-15 16:40:29.807613: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# TPU
t0 = time.time()
# !python MLME-v2.0-conv_model.py -lr 0.01 -bs 32 -ep 20 -pa 5
print(time.time()-t0)
# Out:
# 2021-06-15 16:43:15.139439: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-15 16:43:24.873783: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-15 16:43:24.965550: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-06-15 16:43:24.965619: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (cf7e7fe43e38): /proc/driver/nvidia/version does not exist
# 2021-06-15 16:43:25.463445: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-06-15 16:43:25.463516: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# ...
