# %% [markdown]
# This notebook contains functionality to perform the following:
#
# Define a dataset for training, and an out-of-domain dataset for validation. To test transfer learning success, train either a feed-forward, convolutional, or recurrent neural network on the training dataset, then evaluate this dataset on the validation set.

# %%
# mount google drive

from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/Shareddrives/NRC_Amii_Agronomics_Project/nrc-ml-plant-genomics/'
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/NRC_Amii_Agronomics_Project/nrc-ml-plant-genomics

# %%
import argparse
import keras
import warnings, logging
import numpy as np
import pandas as pd
import datetime, time, os
import json
import random
import tensorflow as tf
import math

from keras.models import Sequential, load_model, model_from_json
from keras.layers import Input, Dense, Conv1D, MaxPooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam  # https://stackoverflow.com/questions/62707558/importerror-cannot-import-name-adam-from-keras-optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping  # https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/
from collections import Counter

from sklearn.metrics import r2_score, accuracy_score
from scipy.stats import spearmanr  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html

warnings.filterwarnings('ignore')
logging.disable(1000)

# tf.random.set_seed(1202)  # https://www.tensorflow.org/api_docs/python/tf/random/set_seed
# from numpy.random import seed
# seed(1202)

random.seed(1234)

nts = ["A", "T", "C", "G"]  # list of single nucleotides

def Spearman(y_true, y_pred):
     return (tf.py_function(spearmanr, [tf.cast(y_pred, tf.float32), 
                       tf.cast(y_true, tf.float32)], Tout = tf.float32) )

# %%
# load in datasets
# validation = pd.read_csv("data/processed/validation.csv")
# arabidopsis = pd.read_csv("data/processed/arabidopsis_processed_every16_padded.csv")

# validation = pd.read_csv("data/processed/validation_padded.csv")
# arabidopsis = pd.read_csv("data/processed/drosophila_processed.csv")

# train on ATAC data, test on tobacco
# validation = pd.read_csv("data/processed/validation_padded.csv")
# arabidopsis = pd.read_csv("data/processed/napus_processed_every16.csv")

# train on arabidopsis genome data, test on arabidopsis bac data (both 153 bp length)
# validation = pd.read_csv("data/processed/arabidopsis_bac.csv")
# arabidopsis = pd.read_csv("data/processed/arabidopsis_processed_every16_padded.csv")

# # train on drosophila genome data, test on arabidopsis bac data (bac padded to 249 bp)
# validation = pd.read_csv("data/processed/arabidopsis_bac_padded.csv")
# arabidopsis = pd.read_csv("data/processed/drosophila_processed.csv")

# train on arabidopsis bac data, test on tobacco data (no padding)
validation = pd.read_csv("data/processed/validation.csv")
arabidopsis = pd.read_csv("data/processed/arabidopsis_bac_10chunks.csv")

# # train on arabidopsis genome data, test on tobacco data (arabidopsis padded to 153 bp)
# validation = pd.read_csv("data/processed/validation.csv")
# arabidopsis = pd.read_csv("data/processed/arabidopsis_processed_every16_padded.csv")

# # train on arabidopsis bac data, test on athal genome data (genome padded to 153)
# arabidopsis = pd.read_csv("data/processed/arabidopsis_bac_10chunks.csv")
# validation = pd.read_csv("data/processed/arabidopsis_processed_every16_padded.csv")

# # train on arabidopsis genome data, test on athal bac data (genome padded to 153)
# validation = pd.read_csv("data/processed/arabidopsis_bac_10chunks.csv")
# arabidopsis = pd.read_csv("data/processed/arabidopsis_processed_every16_padded.csv")

# # train on arabidopsis genome data, test on athal bac data (genome padded to 153)
# validation = pd.read_csv("data/processed/napus_processed_every4_binary.csv")
# arabidopsis = pd.read_csv("data/processed/napus_processed_every4_binary.csv")

# %% [markdown]
# ## Frequency-Based Model

# %%
args = {"target_name":"target",
        "include_mononuc_freq":1,
        "include_dinuc_freq":0,
        "include_trinuc_freq":1,
        "layer_1_size":64,
        "layer_1_activation":"relu",
        "layer_2_size":24,
        "layer_2_activation":"relu",
        "layer_3_size":0,
        "layer_2_activation":"relu",
        "output_layer_size":1,
        "output_layer_activation":"sigmoid",  # change to change ["linear", "sigmoid"]
        "loss":"binary_crossentropy",  # change to change ["mean_squared_error", "binary_crossentropy"]
        "extra_metric":"accuracy",  # change to change [Spearman, "accuracy"]
        'learning_rate':0.002,
        'batch_size':512,
        'num_epochs':100,
        'patience':20,
        'max_batch_steps':-1,
        'optimizer':'adam',
        'verbose_training':1}

# %%
def get_model(args, in_dim):  # initializes model architecture
    mdl = Sequential()

    # this is the only layer that is enforced. to test linear regression only, set layer_1_size to 1 and layer_1_activation to "linear"
    mdl.add(Dense(args["layer_1_size"], input_dim=in_dim, activation=args["layer_1_activation"]))

    if args["layer_2_size"] > 0:       mdl.add(Dense(args["layer_2_size"], activation=args["layer_2_activation"]))
    if args["layer_3_size"] > 0:       mdl.add(Dense(args["layer_3_size"], activation=args["layer_3_activation"]))
    if args["output_layer_size"] > 0:  mdl.add(Dense(args["output_layer_size"], activation=args["output_layer_activation"]))

    return mdl

# %%
def train_test_val(args, df):
    include = []  # captures all sequences we are including as input features

    if args["include_mononuc_freq"] == 1:  include += nts
    if args["include_dinuc_freq"] == 1:    include += [nt1+nt2 for nt1 in nts for nt2 in nts]
    if args["include_trinuc_freq"] == 1:   include += [nt1+nt2+nt3 for nt1 in nts for nt2 in nts for nt3 in nts]

    for item in include:  # create new columns with the counts of sequences in "include"
      print("including", item)
      df[item] = df.sequence.str.count(item)

    # add numbers to fill out for the extra NTs'

    train_df = df[df.set == "train"]
    X_train = np.array(train_df[include])
    y_train = np.array(train_df["target"].tolist())

    val_df = df[df.set == "val"]
    X_val = np.array(val_df[include])
    y_val = np.array(val_df["target"].tolist())

    test_df = df[df.set == "test"]
    X_test = np.array(test_df[include])
    y_test = np.array(test_df["target"].tolist())

    return X_train, y_train, X_val, y_val, X_test, y_test


def prepare_validation(args, df):
    include = []  # captures all sequences we are including as input features

    if args["include_mononuc_freq"] == 1:  include += nts
    if args["include_dinuc_freq"] == 1:    include += [nt1+nt2 for nt1 in nts for nt2 in nts]
    if args["include_trinuc_freq"] == 1:   include += [nt1+nt2+nt3 for nt1 in nts for nt2 in nts for nt3 in nts]

    for item in include:  # create new columns with the counts of sequences in "include"
      print("including", item)
      df[item] = df.sequence.str.count(item)

    X_test = np.array(df[include])
    y_test = np.array(df["target"].tolist())

    return X_test, y_test

# %%
X_train, y_train, X_val, y_val, X_test, y_test = train_test_val(args, arabidopsis)
X_real, y_real = prepare_validation(args, validation)
# Out:
# including A
# including T
# including C
# including G
# including AAA
# including AAT
# including AAC
# including AAG
# including ATA
# including ATT
# including ATC
# including ATG
# including ACA
# including ACT
# including ACC
# including ACG
# including AGA
# including AGT
# including AGC
# including AGG
# including TAA
# including TAT
# including TAC
# including TAG
# including TTA
# including TTT
# including TTC
# including TTG
# including TCA
# including TCT
# including TCC
# including TCG
# including TGA
# including TGT
# including TGC
# including TGG
# including CAA
# including CAT
# including CAC
# including CAG
# including CTA
# including CTT
# including CTC
# including CTG
# including CCA
# including CCT
# including CCC
# including CCG
# including CGA
# including CGT
# including CGC
# including CGG
# including GAA
# including GAT
# including GAC
# including GAG
# including GTA
# including GTT
# including GTC
# including GTG
# including GCA
# including GCT
# including GCC
# including GCG
# including GGA
# including GGT
# including GGC
# including GGG
# including A
# including T
# including C
# including G
# including AAA
# including AAT
# including AAC
# including AAG
# including ATA
# including ATT
# including ATC
# including ATG
# including ACA
# including ACT
# including ACC
# including ACG
# including AGA
# including AGT
# including AGC
# including AGG
# including TAA
# including TAT
# including TAC
# including TAG
# including TTA
# including TTT
# including TTC
# including TTG
# including TCA
# including TCT
# including TCC
# including TCG
# including TGA
# including TGT
# including TGC
# including TGG
# including CAA
# including CAT
# including CAC
# including CAG
# including CTA
# including CTT
# including CTC
# including CTG
# including CCA
# including CCT
# including CCC
# including CCG
# including CGA
# including CGT
# including CGC
# including CGG
# including GAA
# including GAT
# including GAC
# including GAG
# including GTA
# including GTT
# including GTC
# including GTG
# including GCA
# including GCT
# including GCC
# including GCG
# including GGA
# including GGT
# including GGC
# including GGG

# %%
model = get_model(args, X_train.shape[1])  # initalize model

# inner_path = "validation_results/arabidopsis/train_on_athal_bac_val_on_athal_genome"
# inner_path = "validation_results/arabidopsis/train_on_athal_genome_val_on_athal_bac/freq"
inner_path = "accessibility_task/2_percent_binary"

# create path to folder with results 
dir_path = ("experiments/"+inner_path+"/nucfreq"
            +"_"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
            +"_"+args["target_name"]
            +"_nuc"
            +str(args["include_mononuc_freq"])
            +str(args["include_dinuc_freq"])
            +str(args["include_trinuc_freq"])
            +"_lay"+str(args["layer_1_size"])
            +"-"+str(args["layer_2_size"])
            +"-"+str(args["layer_3_size"])
            +"-"+str(args["output_layer_size"])
            +"_lr"+str(args["learning_rate"])
            +"_bs"+str(args["batch_size"])
            +'_rep5')


# for binary task
model.compile(optimizer=Adam(lr=args["learning_rate"]),  # CHANGE IF WE WANT TO CHANGE OPTIM
              loss=args["loss"],
              metrics=[args["extra_metric"]])

# %%
logdir = os.path.join(dir_path, "logs")
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)  # https://stackoverflow.com/questions/59894720/keras-and-tensorboard-attributeerror-sequential-object-has-no-attribute-g
es_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=args["patience"], restore_best_weights=True)
mc_callback = ModelCheckpoint(dir_path+'/best_model.h5', monitor='val_loss', save_best_only=True)

# %%
history = model.fit(X_train, y_train,
                    epochs=args["num_epochs"],
                    batch_size=args["batch_size"],
                    validation_data=(X_val, y_val),
                    callbacks=[tensorboard_callback, es_callback, mc_callback])

hist_df = pd.DataFrame(history.history) 
hist_df.to_csv(dir_path+'/training_history.csv')
# Out:
# Epoch 1/100
# 581/581 [==============================] - 3s 4ms/step - loss: 0.0889 - accuracy: 0.9761 - val_loss: 0.0310 - val_accuracy: 0.9914
# Epoch 2/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 0.0317 - val_accuracy: 0.9894
# Epoch 3/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.0276 - val_accuracy: 0.9917
# Epoch 4/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.0287 - val_accuracy: 0.9915
# Epoch 5/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0284 - accuracy: 0.9907 - val_loss: 0.0263 - val_accuracy: 0.9917
# Epoch 6/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0277 - accuracy: 0.9908 - val_loss: 0.0269 - val_accuracy: 0.9916
# Epoch 7/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.0289 - val_accuracy: 0.9915
# Epoch 8/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0269 - accuracy: 0.9910 - val_loss: 0.0275 - val_accuracy: 0.9915
# Epoch 9/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.0263 - val_accuracy: 0.9919
# Epoch 10/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 11/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.0275 - val_accuracy: 0.9911
# Epoch 12/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.0271 - val_accuracy: 0.9916
# Epoch 13/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 0.0267 - val_accuracy: 0.9914
# Epoch 14/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.0273 - val_accuracy: 0.9913
# Epoch 15/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0300 - val_accuracy: 0.9908
# Epoch 16/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0270 - val_accuracy: 0.9916
# Epoch 17/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0238 - accuracy: 0.9921 - val_loss: 0.0269 - val_accuracy: 0.9919
# Epoch 18/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0273 - val_accuracy: 0.9914
# Epoch 19/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0265 - val_accuracy: 0.9921
# Epoch 20/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0271 - val_accuracy: 0.9916
# Epoch 21/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.0263 - val_accuracy: 0.9923
# Epoch 22/100
# 581/581 [==============================] - 2s 4ms/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 0.0261 - val_accuracy: 0.9918
# Epoch 23/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.0260 - val_accuracy: 0.9918
# Epoch 24/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0256 - val_accuracy: 0.9922
# Epoch 25/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.0263 - val_accuracy: 0.9923
# Epoch 26/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0215 - accuracy: 0.9931 - val_loss: 0.0264 - val_accuracy: 0.9919
# Epoch 27/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.0273 - val_accuracy: 0.9920
# Epoch 28/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0281 - val_accuracy: 0.9919
# Epoch 29/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.0268 - val_accuracy: 0.9921
# Epoch 30/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 31/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.0264 - val_accuracy: 0.9922
# Epoch 32/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.0265 - val_accuracy: 0.9922
# Epoch 33/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0274 - val_accuracy: 0.9916
# Epoch 34/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.0261 - val_accuracy: 0.9926
# Epoch 35/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0277 - val_accuracy: 0.9917
# Epoch 36/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.0300 - val_accuracy: 0.9915
# Epoch 37/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0283 - val_accuracy: 0.9916
# Epoch 38/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0194 - accuracy: 0.9935 - val_loss: 0.0277 - val_accuracy: 0.9917
# Epoch 39/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0316 - val_accuracy: 0.9906
# Epoch 40/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0289 - val_accuracy: 0.9915
# Epoch 41/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.0321 - val_accuracy: 0.9909
# Epoch 42/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0271 - val_accuracy: 0.9923
# Epoch 43/100
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.0276 - val_accuracy: 0.9917
# Epoch 44/100
# 580/581 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9937Restoring model weights from the end of the best epoch: 24.
# 581/581 [==============================] - 2s 3ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0298 - val_accuracy: 0.9915
# Epoch 44: early stopping

# %%
# load best model according to val_loss

# saved_model = load_model(dir_path+'/best_model.h5')
saved_model = model

# with open(dir_path+"/results.csv", "w") as f:
#   f.write(",R2,spearman\n")
#   f.write("train,"+str(r2_score(y_train, saved_model.predict(X_train).reshape(1, -1)[0]))+","+str(spearmanr(y_train, saved_model.predict(X_train).reshape(1, -1)[0])[0])+"\n")
#   f.write("val,"+str(r2_score(y_val, saved_model.predict(X_val).reshape(1, -1)[0]))+","+str(spearmanr(y_val, saved_model.predict(X_val).reshape(1, -1)[0])[0])+"\n")
#   f.write("test,"+str(r2_score(y_test, saved_model.predict(X_test).reshape(1, -1)[0]))+","+str(spearmanr(y_test, saved_model.predict(X_test).reshape(1, -1)[0])[0])+"\n")
#   f.write("real,"+str(r2_score(y_real, saved_model.predict(X_real).reshape(1, -1)[0]))+","+str(spearmanr(y_real, saved_model.predict(X_real).reshape(1, -1)[0])[0]))

# # for real_valued
# with open(dir_path+"/results.csv", "w") as f:
#   f.write(",train,val,test,real\n")
#   f.write("r2,"+str(r2_score(y_train, saved_model.predict(X_train).reshape(1, -1)[0]))+","+str(r2_score(y_val, saved_model.predict(X_val).reshape(1, -1)[0]))+","+str(r2_score(y_test, saved_model.predict(X_test).reshape(1, -1)[0]))+","+str(r2_score(y_real, saved_model.predict(X_real).reshape(1, -1)[0]))+"\n")
#   f.write("spearman,"+str(spearmanr(y_train, saved_model.predict(X_train).reshape(1, -1)[0])[0])+","+str(spearmanr(y_val, saved_model.predict(X_val).reshape(1, -1)[0])[0])+","+str(spearmanr(y_test, saved_model.predict(X_test).reshape(1, -1)[0])[0])+","+str(spearmanr(y_real, saved_model.predict(X_real).reshape(1, -1)[0])[0])+"\n")

# for binary
with open(dir_path+"/results.csv", "w") as f:
  f.write(",train,val,test\n")
  # https://stackoverflow.com/questions/68836551/keras-attributeerror-sequential-object-has-no-attribute-predict-classes
  f.write("accuracy,"+str(accuracy_score(y_train, (saved_model.predict(X_train) > 0.5).astype("int32")))+","+str(accuracy_score(y_val, (saved_model.predict(X_val) > 0.5).astype("int32")))+","+str(accuracy_score(y_test, (saved_model.predict(X_test) > 0.5).astype("int32")))+"\n")

# %% [markdown]
# ## Convolution-Based Model
# Train from scratch

# %%
from keras.models import Sequential, load_model, model_from_json
from keras.layers import Input, Dense, Conv1D, MaxPooling2D, Dropout, Flatten, BatchNormalization
# from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam  # https://stackoverflow.com/questions/62707558/importerror-cannot-import-name-adam-from-keras-optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping  # https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/

from sklearn.metrics import r2_score
from scipy.stats import spearmanr  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html

warnings.filterwarnings('ignore')
logging.disable(1000)

random.seed(1234)

mapping = {"A": [1, 0, 0, 0], "T": [0, 0, 0, 1], "C": [0, 1, 0, 0], "G": [0, 0, 1, 0], "X":[0, 0, 0, 0]}  # cross referenced with kipoi data loader

# %%
args = {"input_sequence_length":153,  # CHANGE WITH DATASET
        "target_name":"target",
        "number_of_outputs":1,
        "conv_one_set":2,
        "conv_two_set":2,
        "conv_three_set":0,
        "model_path":"models/model_genome.json",
        "weights_path":"models/weights_genome.h5",
        "linear_mapping":0,
        "last_conv_layer":1,
        "shuffle":0,
        'learning_rate':0.002,
        'batch_size':512,
        'num_epochs':100,
        'patience':20,
        'max_batch_steps':-1,
        'optimizer':'adam',
        'verbose_training':1}

# %%
def train_test_val(args, df):  # splits dataframe into all the sets
    if args["shuffle"] == 1:  # shuffles NTs within each sequence
      df.loc[:,"sequence"] = [''.join(random.sample(s, len(s))) for s in df["sequence"]]

    train_df = df[df.set == "train"]
    X_train = np.array([get_ohe(sqnc) for sqnc in train_df["sequence"]])
    y_train = np.array(train_df[args["target_name"]].tolist())

    val_df = df[df.set == "val"]
    X_val = np.array([get_ohe(sqnc) for sqnc in val_df["sequence"]])
    y_val = np.array(val_df[args["target_name"]].tolist())

    test_df = df[df.set == "test"]
    X_test = np.array([get_ohe(sqnc) for sqnc in test_df["sequence"]])
    y_test = np.array(test_df[args["target_name"]].tolist())

    return X_train, y_train, X_val, y_val, X_test, y_test


def prepare_validation(df):
    X_test = np.array([get_ohe(sqnc) for sqnc in df["sequence"]])
    y_test = np.array(df["target"].tolist())

    return X_test, y_test


def get_ohe(sequence):  # gets sequence in format model can use (145, 4)
    return np.array([mapping[nt] for nt in sequence])


def get_model(args):  # initializes model architecture
    mdl = Sequential()

    conv1_train = args["conv_one_set"] != 2  # True if conv layer should be trained
    mdl.add(Conv1D(120, 5, activation='relu', input_shape=(args["input_sequence_length"], 4), name="1DConv_1", trainable=conv1_train))
    mdl.add(BatchNormalization(name="batchNorm1", trainable=conv1_train))
    mdl.add(Dropout(0.1, name="drop1"))

    conv2_train = args["conv_two_set"] != 2  # True if conv layer should be trained
    mdl.add(Conv1D(120, 5, activation='relu', name="1DConv_2", trainable=conv2_train))
    mdl.add(BatchNormalization(name="batchNorm2", trainable=conv2_train))
    mdl.add(Dropout(0.1, name="drop2"))

    if args["last_conv_layer"] == 1:  # if we are not removing last conv layer for simplicity
      conv3_train = args["conv_three_set"] != 2  # True if conv layer should be trained
      mdl.add(Conv1D(120, 5, activation='relu', name="1DConv_3", trainable=conv3_train))
      mdl.add(BatchNormalization(name="batchNorm3", trainable=conv3_train))
      mdl.add(Dropout(0.1, name="drop3"))

    mdl.add(Flatten(name="flat"))

    if args["linear_mapping"] == 1: 
        mdl.add(Dense(12, activation='linear', name="dense1", trainable=False))

    # output layer
    mdl.add(Dense(1, activation='linear', name="dense2"))

    return mdl

# %%
X_train, y_train, X_val, y_val, X_test, y_test = train_test_val(args, arabidopsis)
X_real, y_real = prepare_validation(validation)

# %%
model = get_model(args)  # initalize model

# create path to folder with results 
date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
arch_settings = str(args["conv_one_set"])+str(args["conv_two_set"])+str(args["conv_three_set"])+str(args["linear_mapping"])
dir_path = "experiments/conv_validation_"+date+"_"+args["target_name"]+"_"+arch_settings+"_lr"+str(args['learning_rate'])+"_bs"+str(args['batch_size'])+"_ep"+str(args['num_epochs'])

model.compile(optimizer=Adam(lr=args["learning_rate"]),  # CHANGE IF WE WANT TO CHANGE OPTIM
              loss='mean_squared_error',
              metrics=[Spearman])

# %%
logdir = os.path.join(dir_path, "logs")
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)  # https://stackoverflow.com/questions/59894720/keras-and-tensorboard-attributeerror-sequential-object-has-no-attribute-g
es_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=args["patience"], restore_best_weights=True)
mc_callback = ModelCheckpoint(dir_path+'/best_model.h5', monitor='val_loss', save_best_only=True)

# %%
history = model.fit(X_train, y_train,
                    epochs=args["num_epochs"],
                    batch_size=args["batch_size"],
                    validation_data=(X_val, y_val),
                    callbacks=[tensorboard_callback, es_callback, mc_callback])

hist_df = pd.DataFrame(history.history) 
hist_df.to_csv(dir_path+'/training_history.csv')
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 64ms/step - loss: 0.9292 - Spearman: 0.4722 - val_loss: 0.5688 - val_Spearman: 0.5376
# Epoch 2/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.3777 - Spearman: 0.7362 - val_loss: 0.5631 - val_Spearman: 0.6643
# Epoch 3/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.2844 - Spearman: 0.7993 - val_loss: 0.5978 - val_Spearman: 0.6733
# Epoch 4/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.2522 - Spearman: 0.8264 - val_loss: 0.5580 - val_Spearman: 0.6916
# Epoch 5/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.2338 - Spearman: 0.8358 - val_loss: 0.5579 - val_Spearman: 0.6985
# Epoch 6/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.2193 - Spearman: 0.8470 - val_loss: 0.5452 - val_Spearman: 0.6984
# Epoch 7/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.2174 - Spearman: 0.8491 - val_loss: 0.5678 - val_Spearman: 0.7002
# Epoch 8/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.2036 - Spearman: 0.8542 - val_loss: 0.5460 - val_Spearman: 0.6963
# Epoch 9/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1949 - Spearman: 0.8617 - val_loss: 0.5357 - val_Spearman: 0.6679
# Epoch 10/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.1925 - Spearman: 0.8615 - val_loss: 0.5512 - val_Spearman: 0.6745
# Epoch 11/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1782 - Spearman: 0.8698 - val_loss: 0.5399 - val_Spearman: 0.6551
# Epoch 12/100
# 11/11 [==============================] - 0s 35ms/step - loss: 0.1775 - Spearman: 0.8715 - val_loss: 0.5567 - val_Spearman: 0.6293
# Epoch 13/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1665 - Spearman: 0.8757 - val_loss: 0.5221 - val_Spearman: 0.6693
# Epoch 14/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1634 - Spearman: 0.8797 - val_loss: 0.5333 - val_Spearman: 0.6751
# Epoch 15/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1583 - Spearman: 0.8814 - val_loss: 0.5441 - val_Spearman: 0.6551
# Epoch 16/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1513 - Spearman: 0.8869 - val_loss: 0.5327 - val_Spearman: 0.6579
# Epoch 17/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1500 - Spearman: 0.8885 - val_loss: 0.5269 - val_Spearman: 0.6463
# Epoch 18/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1410 - Spearman: 0.8948 - val_loss: 0.5317 - val_Spearman: 0.6401
# Epoch 19/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1378 - Spearman: 0.8946 - val_loss: 0.5215 - val_Spearman: 0.6249
# Epoch 20/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1359 - Spearman: 0.8992 - val_loss: 0.5156 - val_Spearman: 0.6396
# Epoch 21/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1270 - Spearman: 0.9032 - val_loss: 0.5119 - val_Spearman: 0.6285
# Epoch 22/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1254 - Spearman: 0.9031 - val_loss: 0.4982 - val_Spearman: 0.6096
# Epoch 23/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1233 - Spearman: 0.9063 - val_loss: 0.4876 - val_Spearman: 0.6279
# Epoch 24/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1205 - Spearman: 0.9059 - val_loss: 0.4898 - val_Spearman: 0.6171
# Epoch 25/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1172 - Spearman: 0.9075 - val_loss: 0.4914 - val_Spearman: 0.6461
# Epoch 26/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1166 - Spearman: 0.9089 - val_loss: 0.4955 - val_Spearman: 0.6120
# Epoch 27/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1084 - Spearman: 0.9139 - val_loss: 0.4811 - val_Spearman: 0.5992
# Epoch 28/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1065 - Spearman: 0.9147 - val_loss: 0.4700 - val_Spearman: 0.6014
# Epoch 29/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1036 - Spearman: 0.9169 - val_loss: 0.4706 - val_Spearman: 0.5994
# Epoch 30/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1035 - Spearman: 0.9166 - val_loss: 0.4746 - val_Spearman: 0.5954
# Epoch 31/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.1032 - Spearman: 0.9189 - val_loss: 0.4320 - val_Spearman: 0.6177
# Epoch 32/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1049 - Spearman: 0.9202 - val_loss: 0.4646 - val_Spearman: 0.5734
# Epoch 33/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1018 - Spearman: 0.9203 - val_loss: 0.4264 - val_Spearman: 0.5947
# Epoch 34/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.1025 - Spearman: 0.9191 - val_loss: 0.4420 - val_Spearman: 0.5625
# Epoch 35/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0986 - Spearman: 0.9208 - val_loss: 0.4247 - val_Spearman: 0.5920
# Epoch 36/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0947 - Spearman: 0.9250 - val_loss: 0.4075 - val_Spearman: 0.6194
# Epoch 37/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0946 - Spearman: 0.9261 - val_loss: 0.4199 - val_Spearman: 0.5679
# Epoch 38/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0919 - Spearman: 0.9260 - val_loss: 0.3871 - val_Spearman: 0.6134
# Epoch 39/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0891 - Spearman: 0.9274 - val_loss: 0.3980 - val_Spearman: 0.5879
# Epoch 40/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0881 - Spearman: 0.9277 - val_loss: 0.3983 - val_Spearman: 0.5885
# Epoch 41/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0893 - Spearman: 0.9274 - val_loss: 0.3852 - val_Spearman: 0.5969
# Epoch 42/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0860 - Spearman: 0.9303 - val_loss: 0.3799 - val_Spearman: 0.6000
# Epoch 43/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0862 - Spearman: 0.9285 - val_loss: 0.3762 - val_Spearman: 0.6096
# Epoch 44/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0824 - Spearman: 0.9321 - val_loss: 0.3486 - val_Spearman: 0.5857
# Epoch 45/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0814 - Spearman: 0.9325 - val_loss: 0.3878 - val_Spearman: 0.5815
# Epoch 46/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0829 - Spearman: 0.9314 - val_loss: 0.3520 - val_Spearman: 0.5981
# Epoch 47/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0807 - Spearman: 0.9336 - val_loss: 0.3288 - val_Spearman: 0.5973
# Epoch 48/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0808 - Spearman: 0.9350 - val_loss: 0.3463 - val_Spearman: 0.5708
# Epoch 49/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0796 - Spearman: 0.9355 - val_loss: 0.3515 - val_Spearman: 0.5744
# Epoch 50/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0779 - Spearman: 0.9347 - val_loss: 0.3334 - val_Spearman: 0.5866
# Epoch 51/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0788 - Spearman: 0.9329 - val_loss: 0.3332 - val_Spearman: 0.5902
# Epoch 52/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0767 - Spearman: 0.9370 - val_loss: 0.3555 - val_Spearman: 0.5887
# Epoch 53/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0782 - Spearman: 0.9355 - val_loss: 0.3130 - val_Spearman: 0.5931
# Epoch 54/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0791 - Spearman: 0.9367 - val_loss: 0.3527 - val_Spearman: 0.5958
# Epoch 55/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0764 - Spearman: 0.9378 - val_loss: 0.3269 - val_Spearman: 0.6027
# Epoch 56/100
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0736 - Spearman: 0.9407 - val_loss: 0.3106 - val_Spearman: 0.5773
# Epoch 57/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0736 - Spearman: 0.9392 - val_loss: 0.2949 - val_Spearman: 0.6154
# Epoch 58/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0749 - Spearman: 0.9385 - val_loss: 0.3561 - val_Spearman: 0.5939
# Epoch 59/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0757 - Spearman: 0.9366 - val_loss: 0.3206 - val_Spearman: 0.5590
# Epoch 60/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0739 - Spearman: 0.9380 - val_loss: 0.4055 - val_Spearman: 0.5820
# Epoch 61/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0728 - Spearman: 0.9396 - val_loss: 0.3445 - val_Spearman: 0.5731
# Epoch 62/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0710 - Spearman: 0.9392 - val_loss: 0.3457 - val_Spearman: 0.5895
# Epoch 63/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0710 - Spearman: 0.9385 - val_loss: 0.3048 - val_Spearman: 0.5953
# Epoch 64/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0707 - Spearman: 0.9424 - val_loss: 0.3977 - val_Spearman: 0.5950
# Epoch 65/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0697 - Spearman: 0.9431 - val_loss: 0.3292 - val_Spearman: 0.5991
# Epoch 66/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0697 - Spearman: 0.9424 - val_loss: 0.4313 - val_Spearman: 0.5990
# Epoch 67/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0693 - Spearman: 0.9420 - val_loss: 0.3141 - val_Spearman: 0.5584
# Epoch 68/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0681 - Spearman: 0.9414 - val_loss: 0.3127 - val_Spearman: 0.5827
# Epoch 69/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0683 - Spearman: 0.9418 - val_loss: 0.3226 - val_Spearman: 0.5775
# Epoch 70/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0698 - Spearman: 0.9423 - val_loss: 0.3584 - val_Spearman: 0.5654
# Epoch 71/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0655 - Spearman: 0.9452 - val_loss: 0.4526 - val_Spearman: 0.5876
# Epoch 72/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0676 - Spearman: 0.9426 - val_loss: 0.3276 - val_Spearman: 0.5930
# Epoch 73/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0685 - Spearman: 0.9440 - val_loss: 0.3030 - val_Spearman: 0.5757
# Epoch 74/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0652 - Spearman: 0.9448 - val_loss: 0.2981 - val_Spearman: 0.5783
# Epoch 75/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0642 - Spearman: 0.9466 - val_loss: 0.2978 - val_Spearman: 0.5601
# Epoch 76/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0679 - Spearman: 0.9434 - val_loss: 0.3059 - val_Spearman: 0.5828
# Epoch 77/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0649 - Spearman: 0.9451 - val_loss: 0.2935 - val_Spearman: 0.5922
# Epoch 78/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0670 - Spearman: 0.9434 - val_loss: 0.3383 - val_Spearman: 0.5831
# Epoch 79/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0678 - Spearman: 0.9445 - val_loss: 0.3068 - val_Spearman: 0.5580
# Epoch 80/100
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0681 - Spearman: 0.9441 - val_loss: 0.3767 - val_Spearman: 0.6032
# Epoch 81/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0641 - Spearman: 0.9471 - val_loss: 0.3252 - val_Spearman: 0.5515
# Epoch 82/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0648 - Spearman: 0.9458 - val_loss: 0.3181 - val_Spearman: 0.5718
# Epoch 83/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0665 - Spearman: 0.9447 - val_loss: 0.2792 - val_Spearman: 0.5861
# Epoch 84/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0640 - Spearman: 0.9460 - val_loss: 0.2950 - val_Spearman: 0.5797
# Epoch 85/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0628 - Spearman: 0.9490 - val_loss: 0.3900 - val_Spearman: 0.6047
# Epoch 86/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0632 - Spearman: 0.9465 - val_loss: 0.2807 - val_Spearman: 0.5912
# Epoch 87/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0623 - Spearman: 0.9488 - val_loss: 0.3312 - val_Spearman: 0.5684
# Epoch 88/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0628 - Spearman: 0.9471 - val_loss: 0.2819 - val_Spearman: 0.5843
# Epoch 89/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0631 - Spearman: 0.9467 - val_loss: 0.2806 - val_Spearman: 0.5859
# Epoch 90/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0625 - Spearman: 0.9472 - val_loss: 0.3306 - val_Spearman: 0.5641
# Epoch 91/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0592 - Spearman: 0.9488 - val_loss: 0.3313 - val_Spearman: 0.5644
# Epoch 92/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0634 - Spearman: 0.9489 - val_loss: 0.3001 - val_Spearman: 0.5733
# Epoch 93/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0607 - Spearman: 0.9492 - val_loss: 0.2917 - val_Spearman: 0.5743
# Epoch 94/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0619 - Spearman: 0.9479 - val_loss: 0.3292 - val_Spearman: 0.5502
# Epoch 95/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0586 - Spearman: 0.9499 - val_loss: 0.3640 - val_Spearman: 0.5451
# Epoch 96/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0597 - Spearman: 0.9502 - val_loss: 0.2931 - val_Spearman: 0.5670
# Epoch 97/100
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0638 - Spearman: 0.9462 - val_loss: 0.3456 - val_Spearman: 0.5638
# Epoch 98/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0620 - Spearman: 0.9484 - val_loss: 0.3174 - val_Spearman: 0.5581
# Epoch 99/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0609 - Spearman: 0.9488 - val_loss: 0.3373 - val_Spearman: 0.5652
# Epoch 100/100
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0593 - Spearman: 0.9494 - val_loss: 0.2990 - val_Spearman: 0.5706

# %%
del arabidopsis
del validation

# %%
# load best model according to val_loss

# saved_model = load_model(dir_path+'/best_model.h5')
saved_model = model

with open(dir_path+"/results.csv", "w") as f:
  f.write(",train,val,test,real\n")
  f.write("r2,"+str(r2_score(y_train, saved_model.predict(X_train).reshape(1, -1)[0]))+","+str(r2_score(y_val, saved_model.predict(X_val).reshape(1, -1)[0]))+","+str(r2_score(y_test, saved_model.predict(X_test).reshape(1, -1)[0]))+","+str(r2_score(y_real, saved_model.predict(X_real).reshape(1, -1)[0]))+"\n")
  f.write("spearman,"+str(spearmanr(y_train, saved_model.predict(X_train).reshape(1, -1)[0])[0])+","+str(spearmanr(y_val, saved_model.predict(X_val).reshape(1, -1)[0])[0])+","+str(spearmanr(y_test, saved_model.predict(X_test).reshape(1, -1)[0])[0])+","+str(spearmanr(y_real, saved_model.predict(X_real).reshape(1, -1)[0])[0])+"\n")
  # f.write("spearman2,"+str(Spearman(y_train, saved_model.predict(X_train).reshape(1, -1)[0])[0])+","+str(Spearman(y_val, saved_model.predict(X_val).reshape(1, -1)[0])[0])+","+str(Spearman(y_test, saved_model.predict(X_test).reshape(1, -1)[0])[0])+","+str(Spearman(y_real, saved_model.predict(X_real).reshape(1, -1)[0])[0])+"\n")

# %% [markdown]
# ## Recurrent-Based Model

# %%
from keras.models import Sequential, load_model, model_from_json
from keras.callbacks import ModelCheckpoint, EarlyStopping  # https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/

from keras import layers
from keras import activations

from sklearn.metrics import r2_score
from scipy.stats import spearmanr # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html

warnings.filterwarnings('ignore')
logging.disable(1000)

tf.random.set_seed(1202)  # https://www.tensorflow.org/api_docs/python/tf/random/set_seed

# mapping = {"A": [1, 0, 0, 0], "T": [0, 0, 0, 1], "C": [0, 1, 0, 0], "G": [0, 0, 1, 0], "X":[0, 0, 0, 0]}  # cross referenced with kipoi data loader
mapping = {"A": [1.0, 0.0, 0.0, 0.0], "T": [0.0, 0.0, 0.0, 1.0], "C": [0.0, 1.0, 0.0, 0.0], "G": [0.0, 0.0, 1.0, 0.0], "X":[0.0, 0.0, 0.0, 0.0]}  # cross referenced with kipoi data loader

# %%
args = {"input_sequence_length":249,
        "target_name":"dev_target",
        "num_outs":1,
        "shuffle":0,
        'learning_rate':0.002,
        'batch_size':512,
        'num_epochs':100,
        'patience':20,
        'max_batch_steps':-1,
        'optimizer':'adam',
        'verbose_training':1}

# %%
def get_model(args):
    model = keras.Sequential()

    # Add a LSTM layer with 128 internal units.
    model.add(layers.LSTM(128))

    # Add a Dense layer with 1 units.
    model.add(layers.Dense(args["num_outs"], activation=activations.linear))

    return model


def train_test_val(args, df):  # splits dataframe into all the sets
    if args["shuffle"] == 1:  # shuffles NTs within each sequence
      df.loc[:,"sequence"] = [''.join(random.sample(s, len(s))) for s in df["sequence"]]

    train_df = df[df.set == "train"]
    X_train = np.array([get_ohe(sqnc) for sqnc in train_df["sequence"]])
    y_train = np.array(train_df[args["target_name"]].tolist())

    val_df = df[df.set == "val"]
    X_val = np.array([get_ohe(sqnc) for sqnc in val_df["sequence"]])
    y_val = np.array(val_df[args["target_name"]].tolist())

    test_df = df[df.set == "test"]
    X_test = np.array([get_ohe(sqnc) for sqnc in test_df["sequence"]])
    y_test = np.array(test_df[args["target_name"]].tolist())

    return X_train, y_train, X_val, y_val, X_test, y_test


def prepare_validation(df):
    X_test = np.array([get_ohe(sqnc) for sqnc in df["sequence"]])
    y_test = np.array(df["target"].tolist())

    return X_test, y_test


def get_ohe(sequence):  # gets sequence in format model can use (145, 4)
    return np.array([mapping[nt] for nt in sequence])

# %%
X_train, y_train, X_val, y_val, X_test, y_test = train_test_val(args, arabidopsis)
X_real, y_real = prepare_validation(validation)

# %%
model = get_model(args)  # initalize model

# create path to folder with results 
date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
dir_path = "experiments/recur_validation_"+date+"_"+args["target_name"]+"_lr"+str(args['learning_rate'])+"_bs"+str(args['batch_size'])+"_ep"+str(args['num_epochs'])

model.compile(optimizer=Adam(lr=args["learning_rate"]),  # CHANGE IF WE WANT TO CHANGE OPTIM
              loss='mean_squared_error',
              metrics=[Spearman])

# %%
logdir = os.path.join(dir_path, "logs")
tensorboard_callback = keras.callbacks.TensorBoard(logdir, histogram_freq=1)  # https://stackoverflow.com/questions/59894720/keras-and-tensorboard-attributeerror-sequential-object-has-no-attribute-g
es_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=20, restore_best_weights=True)
mc_callback = ModelCheckpoint(dir_path+'/best_model.h5', monitor='val_loss', save_best_only=True)

# %%
history = model.fit(X_train, y_train,
                    epochs=args["num_epochs"],
                    batch_size=args["batch_size"],
                    validation_data=(X_val, y_val),
                    callbacks=[tensorboard_callback, es_callback, mc_callback])

hist_df = pd.DataFrame(history.history) 
hist_df.to_csv(dir_path+'/training_history.csv')
# Out:
# Epoch 1/100
# 786/786 [==============================] - 29s 35ms/step - loss: 2.3042 - Spearman: 0.0709 - val_loss: 2.3342 - val_Spearman: 0.0355
# Epoch 2/100
# 786/786 [==============================] - 27s 35ms/step - loss: 2.3174 - Spearman: 0.0194 - val_loss: 2.3147 - val_Spearman: 0.0221
# Epoch 3/100
# 786/786 [==============================] - 27s 35ms/step - loss: 2.3150 - Spearman: 0.0278 - val_loss: 2.3070 - val_Spearman: 0.0266
# Epoch 4/100
# 786/786 [==============================] - 27s 34ms/step - loss: 2.3130 - Spearman: 0.0356 - val_loss: 2.3483 - val_Spearman: 0.0257
# Epoch 5/100
# 786/786 [==============================] - 27s 34ms/step - loss: 2.3138 - Spearman: 0.0289 - val_loss: 2.3229 - val_Spearman: 0.0258
# Epoch 6/100
# 786/786 [==============================] - 28s 36ms/step - loss: 2.3121 - Spearman: 0.0306 - val_loss: 2.3014 - val_Spearman: 0.0300
# Epoch 7/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.3066 - Spearman: 0.0566 - val_loss: 2.2331 - val_Spearman: 0.1181
# Epoch 8/100
# 786/786 [==============================] - 27s 35ms/step - loss: 2.2580 - Spearman: 0.1304 - val_loss: 2.2196 - val_Spearman: 0.1254
# Epoch 9/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.2303 - Spearman: 0.1525 - val_loss: 2.2176 - val_Spearman: 0.1283
# Epoch 10/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.2269 - Spearman: 0.1543 - val_loss: 2.2113 - val_Spearman: 0.1307
# Epoch 11/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.2193 - Spearman: 0.1688 - val_loss: 2.2026 - val_Spearman: 0.1534
# Epoch 12/100
# 786/786 [==============================] - 28s 36ms/step - loss: 2.1909 - Spearman: 0.2165 - val_loss: 2.1634 - val_Spearman: 0.2212
# Epoch 13/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.1339 - Spearman: 0.2797 - val_loss: 2.1183 - val_Spearman: 0.2533
# Epoch 14/100
# 786/786 [==============================] - 28s 35ms/step - loss: 2.0655 - Spearman: 0.3345 - val_loss: 1.9813 - val_Spearman: 0.3058
# Epoch 15/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.9567 - Spearman: 0.4007 - val_loss: 1.9003 - val_Spearman: 0.3569
# Epoch 16/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.8240 - Spearman: 0.4641 - val_loss: 1.7935 - val_Spearman: 0.3980
# Epoch 17/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.7195 - Spearman: 0.5041 - val_loss: 1.6821 - val_Spearman: 0.4275
# Epoch 18/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.6479 - Spearman: 0.5283 - val_loss: 1.6291 - val_Spearman: 0.4431
# Epoch 19/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.6030 - Spearman: 0.5447 - val_loss: 1.6035 - val_Spearman: 0.4477
# Epoch 20/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.5608 - Spearman: 0.5561 - val_loss: 1.5621 - val_Spearman: 0.4624
# Epoch 21/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.5293 - Spearman: 0.5658 - val_loss: 1.5257 - val_Spearman: 0.4698
# Epoch 22/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.5029 - Spearman: 0.5737 - val_loss: 1.4800 - val_Spearman: 0.4725
# Epoch 23/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.4784 - Spearman: 0.5809 - val_loss: 1.4907 - val_Spearman: 0.4786
# Epoch 24/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.4558 - Spearman: 0.5864 - val_loss: 1.4662 - val_Spearman: 0.4829
# Epoch 25/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.4311 - Spearman: 0.5925 - val_loss: 1.4330 - val_Spearman: 0.4880
# Epoch 26/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.4147 - Spearman: 0.5966 - val_loss: 1.4417 - val_Spearman: 0.4907
# Epoch 27/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.3962 - Spearman: 0.6013 - val_loss: 1.4286 - val_Spearman: 0.4946
# Epoch 28/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.3863 - Spearman: 0.6046 - val_loss: 1.4093 - val_Spearman: 0.4961
# Epoch 29/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.3697 - Spearman: 0.6081 - val_loss: 1.4336 - val_Spearman: 0.4952
# Epoch 30/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.3583 - Spearman: 0.6108 - val_loss: 1.3988 - val_Spearman: 0.4968
# Epoch 31/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.3467 - Spearman: 0.6135 - val_loss: 1.3929 - val_Spearman: 0.5006
# Epoch 32/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.3347 - Spearman: 0.6167 - val_loss: 1.4067 - val_Spearman: 0.4997
# Epoch 33/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.3216 - Spearman: 0.6193 - val_loss: 1.3949 - val_Spearman: 0.5012
# Epoch 34/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.3117 - Spearman: 0.6217 - val_loss: 1.3911 - val_Spearman: 0.5016
# Epoch 35/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.3012 - Spearman: 0.6241 - val_loss: 1.3982 - val_Spearman: 0.5023
# Epoch 36/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2924 - Spearman: 0.6262 - val_loss: 1.4102 - val_Spearman: 0.5041
# Epoch 37/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2829 - Spearman: 0.6282 - val_loss: 1.4451 - val_Spearman: 0.5011
# Epoch 38/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2716 - Spearman: 0.6302 - val_loss: 1.3981 - val_Spearman: 0.5022
# Epoch 39/100
# 786/786 [==============================] - 28s 35ms/step - loss: 1.2641 - Spearman: 0.6321 - val_loss: 1.3902 - val_Spearman: 0.5016
# Epoch 40/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2550 - Spearman: 0.6346 - val_loss: 1.3957 - val_Spearman: 0.5007
# Epoch 41/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2476 - Spearman: 0.6361 - val_loss: 1.4147 - val_Spearman: 0.4999
# Epoch 42/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2383 - Spearman: 0.6378 - val_loss: 1.3919 - val_Spearman: 0.5027
# Epoch 43/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2311 - Spearman: 0.6397 - val_loss: 1.4027 - val_Spearman: 0.5011
# Epoch 44/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2230 - Spearman: 0.6413 - val_loss: 1.4210 - val_Spearman: 0.5009
# Epoch 45/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2141 - Spearman: 0.6427 - val_loss: 1.4149 - val_Spearman: 0.4980
# Epoch 46/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2101 - Spearman: 0.6442 - val_loss: 1.4100 - val_Spearman: 0.4996
# Epoch 47/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.2006 - Spearman: 0.6462 - val_loss: 1.4084 - val_Spearman: 0.4985
# Epoch 48/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.1948 - Spearman: 0.6471 - val_loss: 1.4449 - val_Spearman: 0.4987
# Epoch 49/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.1885 - Spearman: 0.6480 - val_loss: 1.4166 - val_Spearman: 0.4976
# Epoch 50/100
# 786/786 [==============================] - 27s 35ms/step - loss: 1.1835 - Spearman: 0.6497 - val_loss: 1.4076 - val_Spearman: 0.4998
# Epoch 51/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1771 - Spearman: 0.6514 - val_loss: 1.5024 - val_Spearman: 0.4983
# Epoch 52/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1710 - Spearman: 0.6525 - val_loss: 1.4132 - val_Spearman: 0.4972
# Epoch 53/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1707 - Spearman: 0.6525 - val_loss: 1.4253 - val_Spearman: 0.4975
# Epoch 54/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1615 - Spearman: 0.6553 - val_loss: 1.4845 - val_Spearman: 0.4948
# Epoch 55/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1537 - Spearman: 0.6562 - val_loss: 1.4249 - val_Spearman: 0.4985
# Epoch 56/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1553 - Spearman: 0.6563 - val_loss: 1.4595 - val_Spearman: 0.4975
# Epoch 57/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1467 - Spearman: 0.6583 - val_loss: 1.4456 - val_Spearman: 0.4966
# Epoch 58/100
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1413 - Spearman: 0.6594 - val_loss: 1.4286 - val_Spearman: 0.4957
# Epoch 59/100
# 785/786 [============================>.] - ETA: 0s - loss: 1.1359 - Spearman: 0.6602Restoring model weights from the end of the best epoch: 39.
# 786/786 [==============================] - 27s 34ms/step - loss: 1.1358 - Spearman: 0.6603 - val_loss: 1.4230 - val_Spearman: 0.4971
# Epoch 59: early stopping

# %%
# load best model according to val_loss

# saved_model = load_model(dir_path+'/best_model.h5')
saved_model = model

with open(dir_path+"/results.csv", "w") as f:
  f.write(",train,val,test,real\n")
  f.write("r2,"+str(r2_score(y_train, saved_model.predict(X_train).reshape(1, -1)[0]))+","+str(r2_score(y_val, saved_model.predict(X_val).reshape(1, -1)[0]))+","+str(r2_score(y_test, saved_model.predict(X_test).reshape(1, -1)[0]))+","+str(r2_score(y_real, saved_model.predict(X_real).reshape(1, -1)[0]))+"\n")
  f.write("spearman,"+str(spearmanr(y_train, saved_model.predict(X_train).reshape(1, -1)[0])[0])+","+str(spearmanr(y_val, saved_model.predict(X_val).reshape(1, -1)[0])[0])+","+str(spearmanr(y_test, saved_model.predict(X_test).reshape(1, -1)[0])[0])+","+str(spearmanr(y_real, saved_model.predict(X_real).reshape(1, -1)[0])[0])+"\n")
